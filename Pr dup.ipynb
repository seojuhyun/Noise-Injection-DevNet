# %% [markdown]
# # append 0 VS 1
# - 50 epoch 1Round

# %% [markdown]
# # annthyroid_21feat_normalised

# %%
# append 0

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'

# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'annthyroid_21feat_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_0.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %%
# append 1

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'annthyroid_21feat_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_1.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %% [markdown]
# # bank-additional-full_normalised

# %%
# append 0

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'bank-additional-full_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_0.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %%
# append 1

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'bank-additional-full_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_1.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %% [markdown]
# # KDD2014_donors_10feat_nomissing_normalised

# %%
# append 0

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'KDD2014_donors_10feat_nomissing_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_0.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %%
# append 1

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'KDD2014_donors_10feat_nomissing_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_1.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %% [markdown]
# # celeba_baldvsnonbald_normalised

# %%
# append 0

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'celeba_baldvsnonbald_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_0.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %%
# append 1

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'celeba_baldvsnonbald_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_1.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %% [markdown]
# # census-income-full-mixed-binarized

# %%
# append 0

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'census-income-full-mixed-binarized'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_0.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %%
# append 1

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'census-income-full-mixed-binarized'
previous_model = None

    
# Prepare DevNet commandannthyroid_21feat_normalised
devnet_command = (
    f'python /dev/devnet_1.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %% [markdown]
# # UNSW_NB15_traintest_backdoor

# %%
# append 0

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'UNSW_NB15_traintest_backdoor'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_0.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %%
# append 1

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'UNSW_NB15_traintest_backdoor'
previous_model = None

    
# Prepare DevNet commandannthyroid_21feat_normalised
devnet_command = (
    f'python /dev/devnet_1.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %% [markdown]
# # creditcardfraud_normalised

# %%
# append 0

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'creditcardfraud_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_0.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %%
# append 1

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 1
batch_size = 64
epochs = 50
random_seed= 42
input_path= '/dev'
dataset= 'creditcardfraud_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_1.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %% [markdown]
# # annthyroid_21feat_normalised
# - 10 Round

# %%
# append 0

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 10
batch_size = 64
epochs = 100
random_seed= 42
input_path= '/dev'
dataset= 'annthyroid_21feat_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_0.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %%
# append 1

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 10
batch_size = 64
epochs = 100
random_seed= 42
input_path= '/dev'
dataset= 'annthyroid_21feat_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_1.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %% [markdown]
# # census-income-full-mixed-binarized

# %%
# append 0

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 10
batch_size = 64
epochs = 100
random_seed= 42
input_path= '/dev'
dataset= 'census-income-full-mixed-binarized'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_0.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %%
# append 1

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 10
batch_size = 64
epochs = 100
random_seed= 42
input_path= '/dev'
dataset= 'census-income-full-mixed-binarized'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_1.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %% [markdown]
# # UNSW_NB15_traintest_backdoor

# %%
# append 0

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 10
batch_size = 64
epochs = 100
random_seed= 42
input_path= '/dev'
dataset= 'UNSW_NB15_traintest_backdoor'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_0.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %%
# append 1

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 10
batch_size = 64
epochs = 100
random_seed= 42
input_path= '/dev'
dataset= 'UNSW_NB15_traintest_backdoor'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_1.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %% [markdown]
# # creditcardfraud_normalised

# %%
# append 0

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 10
batch_size = 64
epochs = 100
random_seed= 42
input_path= '/dev'
dataset= 'creditcardfraud_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_0.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")

# %%
# append 1

import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
import shutil
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = ""  # GPU 사용 안함 (필요 시)
os.environ['PYTHONHASHSEED'] = '42'


# Constants and directory setup
SAVED_MODELS_DIR = '/dev'
if not os.path.exists(SAVED_MODELS_DIR):
    os.makedirs(SAVED_MODELS_DIR)

# Model settings
network_depth = 2
runs= 10
batch_size = 64
epochs = 100
random_seed= 42
input_path= '/dev'
dataset= 'creditcardfraud_normalised'
previous_model = None

    
# Prepare DevNet command
devnet_command = (
    f'python /dev/devnet_1.py '
    f'--data_format 0 '
    f'--network_depth {network_depth} '
    f'--runs {runs} '
    f'--batch_size {batch_size} '
    f'--epochs {epochs} '
    f'--output {SAVED_MODELS_DIR} '
    f'--ramdn_seed {random_seed} '
    f'--known_outliers 30 '
    f'--cont_rate 0.02 '
    f'--input_path {input_path}/ '
    f'--data_set {dataset}'
)

        
os.system(devnet_command)

print("Training and testing completed.")
